# %%
# https://towardsdatascience.com/robust-facial-landmarks-for-occluded-angled-faces-925e465cbf2e
# localmente en entorno curso con tf 2.3.1

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
def get_face_detector(modelFile = "models/res10_300x300_ssd_iter_140000.caffemodel",
                      configFile = "models/deploy.prototxt"):
    """
    Get the face detection caffe model of OpenCV's DNN module
    
    Parameters
    ----------
    modelFile : string, optional
        Path to model file. The default is "models/res10_300x300_ssd_iter_140000.caffemodel".
    configFile : string, optional
        Path to config file. The default is "models/deploy.prototxt".
    Returns
    -------
    model : dnn_Net
    """
    modelFile = "models/res10_300x300_ssd_iter_140000.caffemodel"
    configFile = "models/deploy.prototxt"
    model = cv2.dnn.readNetFromCaffe(configFile, modelFile)
    return model

# %%
def find_faces(img, model):
    """
    Find the faces in an image
    
    Parameters
    ----------
    img : np.uint8
        Image to find faces from
    model : dnn_Net
        Face detection model
    Returns
    -------
    faces : list
        List of coordinates of the faces detected in the image
    """
    h, w = img.shape[:2]
    blob = cv2.dnn.blobFromImage(cv2.resize(img, (300, 300)), 1.0,
	(300, 300), (104.0, 177.0, 123.0))
    model.setInput(blob)
    res = model.forward()
    faces = []
    for i in range(res.shape[2]):
        confidence = res[0, 0, i, 2]
        if confidence > 0.5:
            box = res[0, 0, i, 3:7] * np.array([w, h, w, h])
            (x, y, x1, y1) = box.astype("int")
            faces.append([x, y, x1, y1])
    return faces

# %%
def get_landmark_model(saved_model='models/pose_model'):
    """
    Get the facial landmark model. 
    Original repository: https://github.com/yinguobing/cnn-facial-landmark
    Parameters
    ----------
    saved_model : string, optional
        Path to facial landmarks model. The default is 'models/pose_model'.
    Returns
    -------
    model : Tensorflow model
        Facial landmarks model
    """
    model = keras.models.load_model(saved_model)
    return model

# %%
def get_square_box(box):
    """Get a square box out of the given box, by expanding it."""
    left_x = box[0]
    top_y = box[1]
    right_x = box[2]
    bottom_y = box[3]

    box_width = right_x - left_x
    box_height = bottom_y - top_y

    # Check if box is already a square. If not, make it a square.
    diff = box_height - box_width
    delta = int(abs(diff) / 2)

    if diff == 0:                   # Already a square.
        return box
    elif diff > 0:                  # Height > width, a slim box.
        left_x -= delta
        right_x += delta
        if diff % 2 == 1:
            right_x += 1
    else:                           # Width > height, a short box.
        top_y -= delta
        bottom_y += delta
        if diff % 2 == 1:
            bottom_y += 1

    # Make sure box is always square.
    assert ((right_x - left_x) == (bottom_y - top_y)), 'Box is not square.'

    return [left_x, top_y, right_x, bottom_y]

# %%
def move_box(box, offset):
        """Move the box to direction specified by vector offset"""
        left_x = box[0] + offset[0]
        top_y = box[1] + offset[1]
        right_x = box[2] + offset[0]
        bottom_y = box[3] + offset[1]
        return [left_x, top_y, right_x, bottom_y]

# %%
def detect_marks(img, model, face):
    """
    Find the facial landmarks in an image from the faces
    Parameters
    ----------
    img : np.uint8
        The image in which landmarks are to be found
    model : Tensorflow model
        Loaded facial landmark model
    face : list
        Face coordinates (x, y, x1, y1) in which the landmarks are to be found
    Returns
    -------
    marks : numpy array
        facial landmark points
    """

    offset_y = int(abs((face[3] - face[1]) * 0.1))
    box_moved = move_box(face, [0, offset_y])
    facebox = get_square_box(box_moved)
    
    face_img = img[facebox[1]: facebox[3],
                     facebox[0]: facebox[2]]
    face_img = cv2.resize(face_img, (128, 128))
    face_img = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    
    # # Actual detection.
    predictions = model.signatures["predict"](
        tf.constant([face_img], dtype=tf.uint8))
    
    #######################
    #Scores
    #Ariel
    #scores = model.signatures["probabilities"](
    #    tf.constant([face_img], dtype=tf.dt_float))
    
    # get class prediction
    #out = model.forward()
    #pred_probas = out["detection_out"]
    #print(pred_probas.argmax())
    
    # Otra forma
    #layer_name = 'detection_out'
    #model.summary()
    #idx=0
    #probas=model.get_layer(layer_name).output
    #sh=model.blobs[layer_name].data
    #print(sh)
    #probas = np.array(predictions['probabilities']).flatten()[:136]
    #print(probas.shape)
    ###############################
    mouth_l=[60,61,62,63,64]
    
    # Convert predictions to landmarks.
    marks = np.array(predictions['output']).flatten()[:136]
    #print(predictions['output'][0][60])
    
    marks = np.reshape(marks, (-1, 2))
    
    marks *= (facebox[2] - facebox[0])
    marks[:, 0] += facebox[0]
    marks[:, 1] += facebox[1]
    marks = marks.astype(np.uint)
    #print(marks.shape)
    return marks, predictions['output'][0]

def draw_marks(image, marks, pred, color=(0, 255, 0)):
    """
    Draw the facial landmarks on an image
    Parameters
    ----------
    image : np.uint8
        Image on which landmarks are to be drawn.
    marks : list or numpy array
        Facial landmark points
    color : tuple, optional
        Color to which landmarks are to be drawn with. The default is (0, 255, 0).
    Returns
    -------
    None.
    """
    i=0
    mouth_l=[60,61,62,63,64]
    font = cv2.FONT_HERSHEY_PLAIN
    for mark in marks:
        if i in mouth_l:
            cv2.circle(image, (mark[0], mark[1]), 2, color, -1, cv2.LINE_AA)
            cv2.putText(image, str(pred[mouth_l[0]]), (0,31), font, 1, (84, 29, 108), 1, cv2.LINE_AA)
            cv2.putText(image, str(pred[mouth_l[1]]), (0,71), font, 1, (84, 29, 108), 1, cv2.LINE_AA)
            cv2.putText(image, str(pred[mouth_l[2]]), (0,101), font, 1, (84, 29, 108), 1, cv2.LINE_AA)
            cv2.putText(image, str(pred[mouth_l[3]]), (0,121), font, 1, (84, 29, 108), 1, cv2.LINE_AA)
            cv2.putText(image, str(pred[mouth_l[4]]), (0,171), font, 1, (84, 29, 108), 1, cv2.LINE_AA)
        i=i+1

# %%
face_model = get_face_detector()
landmark_model = get_landmark_model()

cap = cv2.VideoCapture(0)
while(True):
    ret, img = cap.read()
    rects = find_faces(img, face_model)
    
    for rect in rects:
        marks, pred = detect_marks(img, landmark_model, rect)
        #print(str(pred[60]),pred[61],pred[62],pred[63],pred[64])
        print (tf.strings.as_string(
        pred[60], precision=-1, scientific=False, shortest=False, width=-1,
        fill='', name=None))
        draw_marks(img, marks, pred)
    cv2.imshow("image", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# tf.Tensor(b'0.576020', shape=(), dtype=string)
# tf.Tensor(b'0.567219', shape=(), dtype=string)
# tf.Tensor(b'0.563500', shape=(), dtype=string)
# tf.Tensor(b'0.567986', shape=(), dtype=string)
# tf.Tensor(b'0.589675', shape=(), dtype=string)
# tf.Tensor(b'0.578326', shape=(), dtype=string)
# tf.Tensor(b'0.575512', shape=(), dtype=string)
# tf.Tensor(b'0.583246', shape=(), dtype=string)
# tf.Tensor(b'0.577511', shape=(), dtype=string)
# tf.Tensor(b'0.576483', shape=(), dtype=string)
# tf.Tensor(b'0.585818', shape=(), dtype=string)
# tf.Tensor(b'0.583238', shape=(), dtype=string)
# tf.Tensor(b'0.570424', shape=(), dtype=string)
# tf.Tensor(b'0.581887', shape=(), dtype=string)
# tf.Tensor(b'0.574632', shape=(), dtype=string)
# tf.Tensor(b'0.574722', shape=(), dtype=string)
# tf.Tensor(b'0.579501', shape=(), dtype=string)
# tf.Tensor(b'0.577699', shape=(), dtype=string)
# tf.Tensor(b'0.577818', shape=(), dtype=string)
# tf.Tensor(b'0.573427', shape=(), dtype=string)
# tf.Tensor(b'0.572516', shape=(), dtype=string)
# tf.Tensor(b'0.575528', shape=(), dtype=string)
# tf.Tensor(b'0.576063', shape=(), dtype=string)
# tf.Tensor(b'0.568597', shape=(), dtype=string)
# tf.Tensor(b'0.568484', shape=(), dtype=string)
# tf.Tensor(b'0.570200', shape=(), dtype=string)
# tf.Tensor(b'0.568134', shape=(), dtype=string)
# tf.Tensor(b'0.570895', shape=(), dtype=string)
# tf.Tensor(b'0.570680', shape=(), dtype=string)
# tf.Tensor(b'0.569408', shape=(), dtype=string)
# tf.Tensor(b'0.572282', shape=(), dtype=string)
# tf.Tensor(b'0.573567', shape=(), dtype=string)
# tf.Tensor(b'0.572885', shape=(), dtype=string)
# tf.Tensor(b'0.577728', shape=(), dtype=string)
# tf.Tensor(b'0.572627', shape=(), dtype=string)
# tf.Tensor(b'0.569287', shape=(), dtype=string)
# tf.Tensor(b'0.571145', shape=(), dtype=string)
# tf.Tensor(b'0.571437', shape=(), dtype=string)
# tf.Tensor(b'0.570212', shape=(), dtype=string)
# tf.Tensor(b'0.574760', shape=(), dtype=string)
# tf.Tensor(b'0.579367', shape=(), dtype=string)
# tf.Tensor(b'0.571410', shape=(), dtype=string)
# tf.Tensor(b'0.568295', shape=(), dtype=string)
# tf.Tensor(b'0.564120', shape=(), dtype=string)
# tf.Tensor(b'0.572668', shape=(), dtype=string)
# tf.Tensor(b'0.569560', shape=(), dtype=string)
# tf.Tensor(b'0.577625', shape=(), dtype=string)
# tf.Tensor(b'0.575472', shape=(), dtype=string)
# tf.Tensor(b'0.574780', shape=(), dtype=string)
# tf.Tensor(b'0.570140', shape=(), dtype=string)
# tf.Tensor(b'0.567855', shape=(), dtype=string)
# tf.Tensor(b'0.567603', shape=(), dtype=string)
# tf.Tensor(b'0.577625', shape=(), dtype=string)
# tf.Tensor(b'0.570673', shape=(), dtype=string)
# tf.Tensor(b'0.570777', shape=(), dtype=string)
# tf.Tensor(b'0.564730', shape=(), dtype=string)
# tf.Tensor(b'0.568967', shape=(), dtype=string)
# tf.Tensor(b'0.566623', shape=(), dtype=string)
# tf.Tensor(b'0.565306', shape=(), dtype=string)
# tf.Tensor(b'0.569504', shape=(), dtype=string)
# tf.Tensor(b'0.567582', shape=(), dtype=string)
# tf.Tensor(b'0.566048', shape=(), dtype=string)
# tf.Tensor(b'0.571204', shape=(), dtype=string)
# tf.Tensor(b'0.565016', shape=(), dtype=string)
# tf.Tensor(b'0.572262', shape=(), dtype=string)
# tf.Tensor(b'0.548328', shape=(), dtype=string)
# tf.Tensor(b'0.554231', shape=(), dtype=string)
# tf.Tensor(b'0.558718', shape=(), dtype=string)
# tf.Tensor(b'0.556549', shape=(), dtype=string)
# tf.Tensor(b'0.546095', shape=(), dtype=string)
# tf.Tensor(b'0.682136', shape=(), dtype=string)
# tf.Tensor(b'0.481531', shape=(), dtype=string)
# tf.Tensor(b'0.518336', shape=(), dtype=string)
# tf.Tensor(b'0.521134', shape=(), dtype=string)
# tf.Tensor(b'0.510648', shape=(), dtype=string)
# tf.Tensor(b'0.531849', shape=(), dtype=string)
# tf.Tensor(b'0.524830', shape=(), dtype=string)
# tf.Tensor(b'0.523011', shape=(), dtype=string)
# tf.Tensor(b'0.518269', shape=(), dtype=string)
# tf.Tensor(b'0.521203', shape=(), dtype=string)
# tf.Tensor(b'0.532622', shape=(), dtype=string)
# tf.Tensor(b'0.521828', shape=(), dtype=string)
# tf.Tensor(b'0.531642', shape=(), dtype=string)
# tf.Tensor(b'0.534211', shape=(), dtype=string)
# tf.Tensor(b'0.524264', shape=(), dtype=string)
# tf.Tensor(b'0.526620', shape=(), dtype=string)
# tf.Tensor(b'0.522036', shape=(), dtype=string)
# tf.Tensor(b'0.523704', shape=(), dtype=string)
# tf.Tensor(b'0.511455', shape=(), dtype=string)
# tf.Tensor(b'0.518243', shape=(), dtype=string)
# tf.Tensor(b'0.513490', shape=(), dtype=string)
# tf.Tensor(b'0.514805', shape=(), dtype=string)
# tf.Tensor(b'0.518315', shape=(), dtype=string)
# tf.Tensor(b'0.519779', shape=(), dtype=string)
# tf.Tensor(b'0.526917', shape=(), dtype=string)
# tf.Tensor(b'0.532344', shape=(), dtype=string)
# tf.Tensor(b'0.534774', shape=(), dtype=string)
# tf.Tensor(b'0.537738', shape=(), dtype=string)
# tf.Tensor(b'0.522599', shape=(), dtype=string)
# tf.Tensor(b'0.512671', shape=(), dtype=string)
# tf.Tensor(b'0.518984', shape=(), dtype=string)
# tf.Tensor(b'0.528016', shape=(), dtype=string)
# tf.Tensor(b'0.533086', shape=(), dtype=string)
# tf.Tensor(b'0.516575', shape=(), dtype=string)
# tf.Tensor(b'0.521788', shape=(), dtype=string)
# tf.Tensor(b'0.525218', shape=(), dtype=string)
# tf.Tensor(b'0.517005', shape=(), dtype=string)
# tf.Tensor(b'0.524033', shape=(), dtype=string)
# tf.Tensor(b'0.523565', shape=(), dtype=string)
# tf.Tensor(b'0.518540', shape=(), dtype=string)
# tf.Tensor(b'0.515140', shape=(), dtype=string)
# tf.Tensor(b'0.522809', shape=(), dtype=string)
# tf.Tensor(b'0.530475', shape=(), dtype=string)
# tf.Tensor(b'0.520583', shape=(), dtype=string)
# tf.Tensor(b'0.532888', shape=(), dtype=string)
# tf.Tensor(b'0.541066', shape=(), dtype=string)
# tf.Tensor(b'0.537669', shape=(), dtype=string)
# tf.Tensor(b'0.516533', shape=(), dtype=string)
# tf.Tensor(b'0.569982', shape=(), dtype=string)
# tf.Tensor(b'0.531409', shape=(), dtype=string)
# tf.Tensor(b'0.535628', shape=(), dtype=string)
# tf.Tensor(b'0.534065', shape=(), dtype=string)
# tf.Tensor(b'0.529692', shape=(), dtype=string)
# tf.Tensor(b'0.542456', shape=(), dtype=string)
# tf.Tensor(b'0.554714', shape=(), dtype=string)
# tf.Tensor(b'0.549797', shape=(), dtype=string)
# tf.Tensor(b'0.561976', shape=(), dtype=string)
# tf.Tensor(b'0.564645', shape=(), dtype=string)
# tf.Tensor(b'0.546599', shape=(), dtype=string)
# tf.Tensor(b'0.542320', shape=(), dtype=string)
# tf.Tensor(b'0.540359', shape=(), dtype=string)
# tf.Tensor(b'0.536461', shape=(), dtype=string)
# tf.Tensor(b'0.529455', shape=(), dtype=string)
# tf.Tensor(b'0.561073', shape=(), dtype=string)
# tf.Tensor(b'0.567746', shape=(), dtype=string)
# tf.Tensor(b'0.542811', shape=(), dtype=string)
# tf.Tensor(b'0.535145', shape=(), dtype=string)
# tf.Tensor(b'0.531121', shape=(), dtype=string)
# tf.Tensor(b'0.532157', shape=(), dtype=string)
# tf.Tensor(b'0.524595', shape=(), dtype=string)
# tf.Tensor(b'0.546522', shape=(), dtype=string)
# tf.Tensor(b'0.558633', shape=(), dtype=string)
# tf.Tensor(b'0.545372', shape=(), dtype=string)
# tf.Tensor(b'0.560469', shape=(), dtype=string)
# tf.Tensor(b'0.543464', shape=(), dtype=string)
# tf.Tensor(b'0.560422', shape=(), dtype=string)
# tf.Tensor(b'0.562428', shape=(), dtype=string)
# tf.Tensor(b'0.559516', shape=(), dtype=string)
# tf.Tensor(b'0.566048', shape=(), dtype=string)
# tf.Tensor(b'0.566605', shape=(), dtype=string)
# tf.Tensor(b'0.553605', shape=(), dtype=string)
# tf.Tensor(b'0.528636', shape=(), dtype=string)
# tf.Tensor(b'0.548667', shape=(), dtype=string)
# tf.Tensor(b'0.537205', shape=(), dtype=string)
# tf.Tensor(b'0.549709', shape=(), dtype=string)
# tf.Tensor(b'0.536698', shape=(), dtype=string)
# tf.Tensor(b'0.565402', shape=(), dtype=string)
# tf.Tensor(b'0.566977', shape=(), dtype=string)
# tf.Tensor(b'0.520169', shape=(), dtype=string)
# tf.Tensor(b'0.560925', shape=(), dtype=string)
# tf.Tensor(b'0.519978', shape=(), dtype=string)
# tf.Tensor(b'0.520741', shape=(), dtype=string)
# tf.Tensor(b'0.518454', shape=(), dtype=string)
# tf.Tensor(b'0.522722', shape=(), dtype=string)
# tf.Tensor(b'0.539093', shape=(), dtype=string)
# tf.Tensor(b'0.532510', shape=(), dtype=string)
# tf.Tensor(b'0.540405', shape=(), dtype=string)
# tf.Tensor(b'0.511689', shape=(), dtype=string)
# tf.Tensor(b'0.537634', shape=(), dtype=string)
# tf.Tensor(b'0.516117', shape=(), dtype=string)
# tf.Tensor(b'0.528304', shape=(), dtype=string)
# tf.Tensor(b'0.514853', shape=(), dtype=string)
# tf.Tensor(b'0.513324', shape=(), dtype=string)
# tf.Tensor(b'0.516496', shape=(), dtype=string)
# tf.Tensor(b'0.524124', shape=(), dtype=string)
# tf.Tensor(b'0.532736', shape=(), dtype=string)
# tf.Tensor(b'0.532629', shape=(), dtype=string)
# tf.Tensor(b'0.546537', shape=(), dtype=string)
# tf.Tensor(b'0.537153', shape=(), dtype=string)
# tf.Tensor(b'0.538096', shape=(), dtype=string)
# tf.Tensor(b'0.548120', shape=(), dtype=string)
# tf.Tensor(b'0.527474', shape=(), dtype=string)
# tf.Tensor(b'0.528069', shape=(), dtype=string)
# tf.Tensor(b'0.521673', shape=(), dtype=string)
# tf.Tensor(b'0.534912', shape=(), dtype=string)
# tf.Tensor(b'0.524882', shape=(), dtype=string)
# tf.Tensor(b'0.547791', shape=(), dtype=string)
# tf.Tensor(b'0.527991', shape=(), dtype=string)
# tf.Tensor(b'0.529571', shape=(), dtype=string)
# tf.Tensor(b'0.537427', shape=(), dtype=string)
# tf.Tensor(b'0.508576', shape=(), dtype=string)
# tf.Tensor(b'0.534453', shape=(), dtype=string)
# tf.Tensor(b'0.521420', shape=(), dtype=string)
# tf.Tensor(b'0.528679', shape=(), dtype=string)
# tf.Tensor(b'0.520099', shape=(), dtype=string)
# tf.Tensor(b'0.522791', shape=(), dtype=string)
# tf.Tensor(b'0.534049', shape=(), dtype=string)
# tf.Tensor(b'0.526331', shape=(), dtype=string)
# tf.Tensor(b'0.515267', shape=(), dtype=string)
# tf.Tensor(b'0.533284', shape=(), dtype=string)
# tf.Tensor(b'0.523595', shape=(), dtype=string)
# tf.Tensor(b'0.523375', shape=(), dtype=string)
# tf.Tensor(b'0.529705', shape=(), dtype=string)
# tf.Tensor(b'0.515475', shape=(), dtype=string)
# tf.Tensor(b'0.518968', shape=(), dtype=string)
# tf.Tensor(b'0.514634', shape=(), dtype=string)
# tf.Tensor(b'0.671070', shape=(), dtype=string)
# tf.Tensor(b'0.522614', shape=(), dtype=string)
# tf.Tensor(b'0.698611', shape=(), dtype=string)
# tf.Tensor(b'0.389979', shape=(), dtype=string)
# tf.Tensor(b'0.336500', shape=(), dtype=string)
# tf.Tensor(b'0.433574', shape=(), dtype=string)
# tf.Tensor(b'0.393826', shape=(), dtype=string)
# tf.Tensor(b'0.524658', shape=(), dtype=string)
# tf.Tensor(b'0.584990', shape=(), dtype=string)
# tf.Tensor(b'0.633267', shape=(), dtype=string)
# tf.Tensor(b'0.694801', shape=(), dtype=string)
# tf.Tensor(b'0.655875', shape=(), dtype=string)
# tf.Tensor(b'0.598596', shape=(), dtype=string)
# tf.Tensor(b'0.575006', shape=(), dtype=string)
# tf.Tensor(b'0.603493', shape=(), dtype=string)
# tf.Tensor(b'0.631848', shape=(), dtype=string)
# tf.Tensor(b'0.643309', shape=(), dtype=string)
# tf.Tensor(b'0.644314', shape=(), dtype=string)
# tf.Tensor(b'0.650670', shape=(), dtype=string)
# tf.Tensor(b'0.667794', shape=(), dtype=string)
# tf.Tensor(b'0.627468', shape=(), dtype=string)
# tf.Tensor(b'0.586463', shape=(), dtype=string)
# tf.Tensor(b'0.444665', shape=(), dtype=string)
# tf.Tensor(b'0.443203', shape=(), dtype=string)
# tf.Tensor(b'0.489029', shape=(), dtype=string)
# tf.Tensor(b'0.500966', shape=(), dtype=string)
# tf.Tensor(b'0.522807', shape=(), dtype=string)
# tf.Tensor(b'0.534391', shape=(), dtype=string)
# tf.Tensor(b'0.541504', shape=(), dtype=string)
# tf.Tensor(b'0.546916', shape=(), dtype=string)
# tf.Tensor(b'0.540458', shape=(), dtype=string)
# tf.Tensor(b'0.545439', shape=(), dtype=string)
# tf.Tensor(b'0.549404', shape=(), dtype=string)
# tf.Tensor(b'0.539451', shape=(), dtype=string)
# tf.Tensor(b'0.537081', shape=(), dtype=string)
# tf.Tensor(b'0.546479', shape=(), dtype=string)
# tf.Tensor(b'0.543764', shape=(), dtype=string)
# tf.Tensor(b'0.546017', shape=(), dtype=string)
# tf.Tensor(b'0.542303', shape=(), dtype=string)
# tf.Tensor(b'0.563390', shape=(), dtype=string)
# tf.Tensor(b'0.557950', shape=(), dtype=string)
# tf.Tensor(b'0.552267', shape=(), dtype=string)
# tf.Tensor(b'0.610999', shape=(), dtype=string)
# tf.Tensor(b'0.597889', shape=(), dtype=string)
# tf.Tensor(b'0.608509', shape=(), dtype=string)
# tf.Tensor(b'0.591946', shape=(), dtype=string)
# tf.Tensor(b'0.575492', shape=(), dtype=string)
# tf.Tensor(b'0.583527', shape=(), dtype=string)
# tf.Tensor(b'0.577778', shape=(), dtype=string)
# tf.Tensor(b'0.582955', shape=(), dtype=string)
# tf.Tensor(b'0.580723', shape=(), dtype=string)
# tf.Tensor(b'0.564845', shape=(), dtype=string)
# tf.Tensor(b'0.577654', shape=(), dtype=string)
# tf.Tensor(b'0.566394', shape=(), dtype=string)
# tf.Tensor(b'0.581596', shape=(), dtype=string)
# tf.Tensor(b'0.559374', shape=(), dtype=string)
# tf.Tensor(b'0.563118', shape=(), dtype=string)
# tf.Tensor(b'0.581919', shape=(), dtype=string)
# tf.Tensor(b'0.566594', shape=(), dtype=string)
# tf.Tensor(b'0.568629', shape=(), dtype=string)
# tf.Tensor(b'0.563038', shape=(), dtype=string)
# tf.Tensor(b'0.576927', shape=(), dtype=string)
# tf.Tensor(b'0.552181', shape=(), dtype=string)
# tf.Tensor(b'0.560789', shape=(), dtype=string)
# tf.Tensor(b'0.565775', shape=(), dtype=string)
# tf.Tensor(b'0.590226', shape=(), dtype=string)
# tf.Tensor(b'0.562189', shape=(), dtype=string)
# tf.Tensor(b'0.557508', shape=(), dtype=string)
# tf.Tensor(b'0.586461', shape=(), dtype=string)
# tf.Tensor(b'0.589442', shape=(), dtype=string)
# tf.Tensor(b'0.585306', shape=(), dtype=string)
# tf.Tensor(b'0.568846', shape=(), dtype=string)
# tf.Tensor(b'0.581113', shape=(), dtype=string)
# tf.Tensor(b'0.572694', shape=(), dtype=string)
# tf.Tensor(b'0.590909', shape=(), dtype=string)
# tf.Tensor(b'0.573810', shape=(), dtype=string)
# tf.Tensor(b'0.577856', shape=(), dtype=string)
# tf.Tensor(b'0.588483', shape=(), dtype=string)
# tf.Tensor(b'0.579076', shape=(), dtype=string)
# tf.Tensor(b'0.570747', shape=(), dtype=string)
# tf.Tensor(b'0.574808', shape=(), dtype=string)
# tf.Tensor(b'0.577812', shape=(), dtype=string)
# tf.Tensor(b'0.590288', shape=(), dtype=string)
# tf.Tensor(b'0.572223', shape=(), dtype=string)
# tf.Tensor(b'0.569441', shape=(), dtype=string)
# tf.Tensor(b'0.568982', shape=(), dtype=string)
# tf.Tensor(b'0.569387', shape=(), dtype=string)
# tf.Tensor(b'0.561627', shape=(), dtype=string)
# tf.Tensor(b'0.585139', shape=(), dtype=string)
# tf.Tensor(b'0.575559', shape=(), dtype=string)
# tf.Tensor(b'0.564888', shape=(), dtype=string)
# tf.Tensor(b'0.564398', shape=(), dtype=string)
# tf.Tensor(b'0.574807', shape=(), dtype=string)
# tf.Tensor(b'0.583355', shape=(), dtype=string)
# tf.Tensor(b'0.567864', shape=(), dtype=string)
# tf.Tensor(b'0.590179', shape=(), dtype=string)
# tf.Tensor(b'0.559365', shape=(), dtype=string)
# tf.Tensor(b'0.565937', shape=(), dtype=string)
# tf.Tensor(b'0.565643', shape=(), dtype=string)
# tf.Tensor(b'0.561113', shape=(), dtype=string)
# tf.Tensor(b'0.563395', shape=(), dtype=string)
# tf.Tensor(b'0.571923', shape=(), dtype=string)
# tf.Tensor(b'0.569765', shape=(), dtype=string)
# tf.Tensor(b'0.564682', shape=(), dtype=string)
# tf.Tensor(b'0.565016', shape=(), dtype=string)
# tf.Tensor(b'0.561322', shape=(), dtype=string)
# tf.Tensor(b'0.597664', shape=(), dtype=string)
# tf.Tensor(b'0.568203', shape=(), dtype=string)
# tf.Tensor(b'0.589947', shape=(), dtype=string)
# tf.Tensor(b'0.574545', shape=(), dtype=string)
# tf.Tensor(b'0.580968', shape=(), dtype=string)
# tf.Tensor(b'0.568420', shape=(), dtype=string)
# tf.Tensor(b'0.581231', shape=(), dtype=string)
# tf.Tensor(b'0.568234', shape=(), dtype=string)
# tf.Tensor(b'0.575988', shape=(), dtype=string)
# tf.Tensor(b'0.574849', shape=(), dtype=string)
# tf.Tensor(b'0.576880', shape=(), dtype=string)
# tf.Tensor(b'0.571105', shape=(), dtype=string)
# tf.Tensor(b'0.578611', shape=(), dtype=string)
# tf.Tensor(b'0.589170', shape=(), dtype=string)
# tf.Tensor(b'0.577481', shape=(), dtype=string)
# tf.Tensor(b'0.558106', shape=(), dtype=string)
# tf.Tensor(b'0.554208', shape=(), dtype=string)
# tf.Tensor(b'0.576469', shape=(), dtype=string)
# tf.Tensor(b'0.574662', shape=(), dtype=string)
# tf.Tensor(b'0.582322', shape=(), dtype=string)
# tf.Tensor(b'0.588458', shape=(), dtype=string)
# tf.Tensor(b'0.575963', shape=(), dtype=string)
# tf.Tensor(b'0.566939', shape=(), dtype=string)
# tf.Tensor(b'0.580040', shape=(), dtype=string)
# tf.Tensor(b'0.569687', shape=(), dtype=string)
# tf.Tensor(b'0.572571', shape=(), dtype=string)
# tf.Tensor(b'0.581075', shape=(), dtype=string)
# tf.Tensor(b'0.569539', shape=(), dtype=string)
# tf.Tensor(b'0.575305', shape=(), dtype=string)
# tf.Tensor(b'0.578630', shape=(), dtype=string)
# tf.Tensor(b'0.580303', shape=(), dtype=string)
# tf.Tensor(b'0.584409', shape=(), dtype=string)
# tf.Tensor(b'0.566072', shape=(), dtype=string)
# tf.Tensor(b'0.568119', shape=(), dtype=string)
# tf.Tensor(b'0.572329', shape=(), dtype=string)
# tf.Tensor(b'0.563255', shape=(), dtype=string)
# tf.Tensor(b'0.585088', shape=(), dtype=string)
# tf.Tensor(b'0.574516', shape=(), dtype=string)
# tf.Tensor(b'0.582932', shape=(), dtype=string)
# tf.Tensor(b'0.586346', shape=(), dtype=string)
# tf.Tensor(b'0.571773', shape=(), dtype=string)
# tf.Tensor(b'0.569178', shape=(), dtype=string)
# tf.Tensor(b'0.565326', shape=(), dtype=string)
# tf.Tensor(b'0.562439', shape=(), dtype=string)
# tf.Tensor(b'0.577121', shape=(), dtype=string)
# tf.Tensor(b'0.550405', shape=(), dtype=string)
# tf.Tensor(b'0.569023', shape=(), dtype=string)
# tf.Tensor(b'0.567519', shape=(), dtype=string)
# tf.Tensor(b'0.552395', shape=(), dtype=string)
# tf.Tensor(b'0.562829', shape=(), dtype=string)
# tf.Tensor(b'0.555765', shape=(), dtype=string)
# tf.Tensor(b'0.541569', shape=(), dtype=string)
# tf.Tensor(b'0.560603', shape=(), dtype=string)
# tf.Tensor(b'0.558660', shape=(), dtype=string)
# tf.Tensor(b'0.567037', shape=(), dtype=string)
# tf.Tensor(b'0.561248', shape=(), dtype=string)
# tf.Tensor(b'0.568232', shape=(), dtype=string)
# tf.Tensor(b'0.569116', shape=(), dtype=string)
# tf.Tensor(b'0.557438', shape=(), dtype=string)
# tf.Tensor(b'0.558561', shape=(), dtype=string)
# tf.Tensor(b'0.564311', shape=(), dtype=string)
# tf.Tensor(b'0.573289', shape=(), dtype=string)
# tf.Tensor(b'0.601945', shape=(), dtype=string)
# tf.Tensor(b'0.571413', shape=(), dtype=string)
# tf.Tensor(b'0.551394', shape=(), dtype=string)
# tf.Tensor(b'0.560426', shape=(), dtype=string)
# tf.Tensor(b'0.558593', shape=(), dtype=string)
# tf.Tensor(b'0.561419', shape=(), dtype=string)
# tf.Tensor(b'0.559460', shape=(), dtype=string)
# tf.Tensor(b'0.550636', shape=(), dtype=string)
# tf.Tensor(b'0.552929', shape=(), dtype=string)
# tf.Tensor(b'0.551687', shape=(), dtype=string)
# tf.Tensor(b'0.550771', shape=(), dtype=string)
# tf.Tensor(b'0.541472', shape=(), dtype=string)
# tf.Tensor(b'0.539906', shape=(), dtype=string)
# tf.Tensor(b'0.529254', shape=(), dtype=string)
# tf.Tensor(b'0.551307', shape=(), dtype=string)
# tf.Tensor(b'0.557152', shape=(), dtype=string)
# tf.Tensor(b'0.553964', shape=(), dtype=string)
# tf.Tensor(b'0.552092', shape=(), dtype=string)
# tf.Tensor(b'0.552258', shape=(), dtype=string)
# tf.Tensor(b'0.554389', shape=(), dtype=string)
# tf.Tensor(b'0.549922', shape=(), dtype=string)
# tf.Tensor(b'0.550788', shape=(), dtype=string)
# tf.Tensor(b'0.551508', shape=(), dtype=string)
# tf.Tensor(b'0.543189', shape=(), dtype=string)
# tf.Tensor(b'0.540433', shape=(), dtype=string)
# tf.Tensor(b'0.548086', shape=(), dtype=string)
# tf.Tensor(b'0.546384', shape=(), dtype=string)
# tf.Tensor(b'0.545573', shape=(), dtype=string)
# tf.Tensor(b'0.540217', shape=(), dtype=string)
# tf.Tensor(b'0.529523', shape=(), dtype=string)
# tf.Tensor(b'0.545099', shape=(), dtype=string)
# tf.Tensor(b'0.546368', shape=(), dtype=string)
# tf.Tensor(b'0.544258', shape=(), dtype=string)
# tf.Tensor(b'0.544236', shape=(), dtype=string)
# tf.Tensor(b'0.545085', shape=(), dtype=string)
# tf.Tensor(b'0.532573', shape=(), dtype=string)
# tf.Tensor(b'0.549756', shape=(), dtype=string)
# tf.Tensor(b'0.534647', shape=(), dtype=string)
# tf.Tensor(b'0.534594', shape=(), dtype=string)
# tf.Tensor(b'0.554671', shape=(), dtype=string)
# tf.Tensor(b'0.549219', shape=(), dtype=string)
# tf.Tensor(b'0.540177', shape=(), dtype=string)
# tf.Tensor(b'0.541602', shape=(), dtype=string)
# tf.Tensor(b'0.551957', shape=(), dtype=string)
# tf.Tensor(b'0.543641', shape=(), dtype=string)
# tf.Tensor(b'0.547076', shape=(), dtype=string)
# tf.Tensor(b'0.548551', shape=(), dtype=string)
# tf.Tensor(b'0.541156', shape=(), dtype=string)
# tf.Tensor(b'0.547130', shape=(), dtype=string)
# tf.Tensor(b'0.552540', shape=(), dtype=string)
# tf.Tensor(b'0.542314', shape=(), dtype=string)
# tf.Tensor(b'0.545397', shape=(), dtype=string)
# tf.Tensor(b'0.541520', shape=(), dtype=string)
# tf.Tensor(b'0.546923', shape=(), dtype=string)
# tf.Tensor(b'0.544988', shape=(), dtype=string)
# tf.Tensor(b'0.555829', shape=(), dtype=string)
# tf.Tensor(b'0.555829', shape=(), dtype=string)
# tf.Tensor(b'0.546293', shape=(), dtype=string)
# tf.Tensor(b'0.542105', shape=(), dtype=string)
# tf.Tensor(b'0.548835', shape=(), dtype=string)
# tf.Tensor(b'0.552650', shape=(), dtype=string)
# tf.Tensor(b'0.550110', shape=(), dtype=string)
# tf.Tensor(b'0.537754', shape=(), dtype=string)
# tf.Tensor(b'0.552344', shape=(), dtype=string)
# tf.Tensor(b'0.554597', shape=(), dtype=string)
# tf.Tensor(b'0.548474', shape=(), dtype=string)
# tf.Tensor(b'0.554091', shape=(), dtype=string)
# tf.Tensor(b'0.550307', shape=(), dtype=string)
# tf.Tensor(b'0.550796', shape=(), dtype=string)
# tf.Tensor(b'0.552838', shape=(), dtype=string)
# tf.Tensor(b'0.559888', shape=(), dtype=string)
# tf.Tensor(b'0.560783', shape=(), dtype=string)
# tf.Tensor(b'0.557544', shape=(), dtype=string)
# tf.Tensor(b'0.546863', shape=(), dtype=string)
# tf.Tensor(b'0.550293', shape=(), dtype=string)
# tf.Tensor(b'0.551719', shape=(), dtype=string)
# tf.Tensor(b'0.547638', shape=(), dtype=string)
# tf.Tensor(b'0.555047', shape=(), dtype=string)
# tf.Tensor(b'0.550349', shape=(), dtype=string)
# tf.Tensor(b'0.549657', shape=(), dtype=string)
# tf.Tensor(b'0.545940', shape=(), dtype=string)
# tf.Tensor(b'0.557357', shape=(), dtype=string)
# tf.Tensor(b'0.546894', shape=(), dtype=string)
# tf.Tensor(b'0.546121', shape=(), dtype=string)
# tf.Tensor(b'0.553007', shape=(), dtype=string)
# tf.Tensor(b'0.549553', shape=(), dtype=string)
# tf.Tensor(b'0.554121', shape=(), dtype=string)
# tf.Tensor(b'0.547098', shape=(), dtype=string)
# tf.Tensor(b'0.549049', shape=(), dtype=string)
# tf.Tensor(b'0.544415', shape=(), dtype=string)
# tf.Tensor(b'0.547034', shape=(), dtype=string)
# tf.Tensor(b'0.548207', shape=(), dtype=string)
# tf.Tensor(b'0.552553', shape=(), dtype=string)
# tf.Tensor(b'0.541513', shape=(), dtype=string)
# tf.Tensor(b'0.547220', shape=(), dtype=string)
# tf.Tensor(b'0.549653', shape=(), dtype=string)
# tf.Tensor(b'0.547487', shape=(), dtype=string)
# tf.Tensor(b'0.551194', shape=(), dtype=string)
# tf.Tensor(b'0.552272', shape=(), dtype=string)
# tf.Tensor(b'0.554388', shape=(), dtype=string)
# tf.Tensor(b'0.553042', shape=(), dtype=string)
# tf.Tensor(b'0.548842', shape=(), dtype=string)
# tf.Tensor(b'0.556103', shape=(), dtype=string)
# tf.Tensor(b'0.552911', shape=(), dtype=string)
# tf.Tensor(b'0.547869', shape=(), dtype=string)
# tf.Tensor(b'0.551199', shape=(), dtype=string)
# tf.Tensor(b'0.541258', shape=(), dtype=string)
# tf.Tensor(b'0.545629', shape=(), dtype=string)
# tf.Tensor(b'0.512672', shape=(), dtype=string)
# tf.Tensor(b'0.511969', shape=(), dtype=string)
# tf.Tensor(b'0.507090', shape=(), dtype=string)
# tf.Tensor(b'0.524967', shape=(), dtype=string)
# tf.Tensor(b'0.533172', shape=(), dtype=string)
# tf.Tensor(b'0.529684', shape=(), dtype=string)
# tf.Tensor(b'0.563240', shape=(), dtype=string)
# tf.Tensor(b'0.601066', shape=(), dtype=string)
# tf.Tensor(b'0.604130', shape=(), dtype=string)
# tf.Tensor(b'0.631360', shape=(), dtype=string)
# tf.Tensor(b'0.596189', shape=(), dtype=string)
# tf.Tensor(b'0.599078', shape=(), dtype=string)
# tf.Tensor(b'0.618622', shape=(), dtype=string)
# tf.Tensor(b'0.600406', shape=(), dtype=string)
# tf.Tensor(b'0.599907', shape=(), dtype=string)
# tf.Tensor(b'0.607437', shape=(), dtype=string)
# tf.Tensor(b'0.586689', shape=(), dtype=string)
# tf.Tensor(b'0.596422', shape=(), dtype=string)
# tf.Tensor(b'0.574383', shape=(), dtype=string)
# tf.Tensor(b'0.593966', shape=(), dtype=string)
# tf.Tensor(b'0.619230', shape=(), dtype=string)
# tf.Tensor(b'0.623982', shape=(), dtype=string)
# tf.Tensor(b'0.615613', shape=(), dtype=string)
# tf.Tensor(b'0.633373', shape=(), dtype=string)
# tf.Tensor(b'0.623150', shape=(), dtype=string)
# tf.Tensor(b'0.610199', shape=(), dtype=string)
# tf.Tensor(b'0.611257', shape=(), dtype=string)
# tf.Tensor(b'0.605857', shape=(), dtype=string)
# tf.Tensor(b'0.597021', shape=(), dtype=string)
# tf.Tensor(b'0.619307', shape=(), dtype=string)
# tf.Tensor(b'0.620133', shape=(), dtype=string)
# tf.Tensor(b'0.600855', shape=(), dtype=string)
# tf.Tensor(b'0.620344', shape=(), dtype=string)
# tf.Tensor(b'0.603129', shape=(), dtype=string)
# tf.Tensor(b'0.617177', shape=(), dtype=string)
# tf.Tensor(b'0.602433', shape=(), dtype=string)
# tf.Tensor(b'0.585445', shape=(), dtype=string)
# tf.Tensor(b'0.622035', shape=(), dtype=string)
# tf.Tensor(b'0.602081', shape=(), dtype=string)
# tf.Tensor(b'0.604800', shape=(), dtype=string)
# tf.Tensor(b'0.597492', shape=(), dtype=string)
# tf.Tensor(b'0.625829', shape=(), dtype=string)
# tf.Tensor(b'0.599899', shape=(), dtype=string)
# tf.Tensor(b'0.614616', shape=(), dtype=string)
# tf.Tensor(b'0.604385', shape=(), dtype=string)
# tf.Tensor(b'0.599161', shape=(), dtype=string)
# tf.Tensor(b'0.604929', shape=(), dtype=string)
# tf.Tensor(b'0.614540', shape=(), dtype=string)
# tf.Tensor(b'0.590583', shape=(), dtype=string)
# tf.Tensor(b'0.615155', shape=(), dtype=string)
# tf.Tensor(b'0.607114', shape=(), dtype=string)
# tf.Tensor(b'0.610452', shape=(), dtype=string)
# tf.Tensor(b'0.630542', shape=(), dtype=string)
# tf.Tensor(b'0.358847', shape=(), dtype=string)
# tf.Tensor(b'0.639892', shape=(), dtype=string)
# tf.Tensor(b'0.613795', shape=(), dtype=string)
# tf.Tensor(b'0.576847', shape=(), dtype=string)
# tf.Tensor(b'0.603718', shape=(), dtype=string)
# tf.Tensor(b'0.585144', shape=(), dtype=string)
# tf.Tensor(b'0.601483', shape=(), dtype=string)
# tf.Tensor(b'0.606393', shape=(), dtype=string)
# tf.Tensor(b'0.614507', shape=(), dtype=string)
# tf.Tensor(b'0.616768', shape=(), dtype=string)
# tf.Tensor(b'0.597047', shape=(), dtype=string)
# tf.Tensor(b'0.591701', shape=(), dtype=string)
# tf.Tensor(b'0.616593', shape=(), dtype=string)
# tf.Tensor(b'0.608147', shape=(), dtype=string)
# tf.Tensor(b'0.588483', shape=(), dtype=string)
# tf.Tensor(b'0.613569', shape=(), dtype=string)
# tf.Tensor(b'0.609993', shape=(), dtype=string)
# tf.Tensor(b'0.607538', shape=(), dtype=string)
# tf.Tensor(b'0.632767', shape=(), dtype=string)
# tf.Tensor(b'0.653755', shape=(), dtype=string)
# tf.Tensor(b'0.602192', shape=(), dtype=string)
# tf.Tensor(b'0.618295', shape=(), dtype=string)
# tf.Tensor(b'0.599228', shape=(), dtype=string)
# tf.Tensor(b'0.666755', shape=(), dtype=string)
# tf.Tensor(b'0.611111', shape=(), dtype=string)
# tf.Tensor(b'0.606203', shape=(), dtype=string)
# tf.Tensor(b'0.590509', shape=(), dtype=string)
# tf.Tensor(b'0.612576', shape=(), dtype=string)
# tf.Tensor(b'0.604880', shape=(), dtype=string)
# tf.Tensor(b'0.612150', shape=(), dtype=string)
# tf.Tensor(b'0.588602', shape=(), dtype=string)
# tf.Tensor(b'0.598859', shape=(), dtype=string)
# tf.Tensor(b'0.594511', shape=(), dtype=string)
# tf.Tensor(b'0.596353', shape=(), dtype=string)
# tf.Tensor(b'0.587036', shape=(), dtype=string)
# tf.Tensor(b'0.603461', shape=(), dtype=string)
# tf.Tensor(b'0.609560', shape=(), dtype=string)
# tf.Tensor(b'0.591035', shape=(), dtype=string)
# tf.Tensor(b'0.611685', shape=(), dtype=string)
# tf.Tensor(b'0.577302', shape=(), dtype=string)
# tf.Tensor(b'0.624311', shape=(), dtype=string)
# tf.Tensor(b'0.616298', shape=(), dtype=string)
# tf.Tensor(b'0.604473', shape=(), dtype=string)
# tf.Tensor(b'0.634662', shape=(), dtype=string)
# tf.Tensor(b'0.584175', shape=(), dtype=string)
# tf.Tensor(b'0.603126', shape=(), dtype=string)
# tf.Tensor(b'0.557470', shape=(), dtype=string)
# tf.Tensor(b'0.584825', shape=(), dtype=string)
# tf.Tensor(b'0.629376', shape=(), dtype=string)
# tf.Tensor(b'0.600617', shape=(), dtype=string)
# tf.Tensor(b'0.580606', shape=(), dtype=string)
# tf.Tensor(b'0.615220', shape=(), dtype=string)
# tf.Tensor(b'0.606314', shape=(), dtype=string)
# tf.Tensor(b'0.614087', shape=(), dtype=string)
# tf.Tensor(b'0.610886', shape=(), dtype=string)
# tf.Tensor(b'0.604954', shape=(), dtype=string)
# tf.Tensor(b'0.608590', shape=(), dtype=string)
# tf.Tensor(b'0.619681', shape=(), dtype=string)
# tf.Tensor(b'0.603468', shape=(), dtype=string)
# tf.Tensor(b'0.604490', shape=(), dtype=string)
# tf.Tensor(b'0.619057', shape=(), dtype=string)
# tf.Tensor(b'0.610564', shape=(), dtype=string)
# tf.Tensor(b'0.601241', shape=(), dtype=string)
# tf.Tensor(b'0.605728', shape=(), dtype=string)
# tf.Tensor(b'0.616258', shape=(), dtype=string)
# tf.Tensor(b'0.628028', shape=(), dtype=string)
# tf.Tensor(b'0.551294', shape=(), dtype=string)
# tf.Tensor(b'0.602952', shape=(), dtype=string)
# tf.Tensor(b'0.612207', shape=(), dtype=string)
# tf.Tensor(b'0.597750', shape=(), dtype=string)
# tf.Tensor(b'0.593428', shape=(), dtype=string)
# tf.Tensor(b'0.630651', shape=(), dtype=string)
# tf.Tensor(b'0.382802', shape=(), dtype=string)
# tf.Tensor(b'0.650477', shape=(), dtype=string)
# tf.Tensor(b'0.599533', shape=(), dtype=string)
# tf.Tensor(b'0.601364', shape=(), dtype=string)
# tf.Tensor(b'0.592759', shape=(), dtype=string)
# tf.Tensor(b'0.574546', shape=(), dtype=string)
# tf.Tensor(b'0.617655', shape=(), dtype=string)
# tf.Tensor(b'0.680039', shape=(), dtype=string)
# tf.Tensor(b'0.519490', shape=(), dtype=string)
# tf.Tensor(b'0.578074', shape=(), dtype=string)
# tf.Tensor(b'0.591958', shape=(), dtype=string)
# tf.Tensor(b'0.525871', shape=(), dtype=string)
# tf.Tensor(b'0.484796', shape=(), dtype=string)
# tf.Tensor(b'0.501041', shape=(), dtype=string)
# tf.Tensor(b'0.503412', shape=(), dtype=string)
# tf.Tensor(b'0.510604', shape=(), dtype=string)
# tf.Tensor(b'0.518520', shape=(), dtype=string)
# tf.Tensor(b'0.523756', shape=(), dtype=string)
# tf.Tensor(b'0.519208', shape=(), dtype=string)
# tf.Tensor(b'0.518325', shape=(), dtype=string)
# tf.Tensor(b'0.523007', shape=(), dtype=string)
# tf.Tensor(b'0.517965', shape=(), dtype=string)
# tf.Tensor(b'0.514791', shape=(), dtype=string)
# tf.Tensor(b'0.513710', shape=(), dtype=string)
# tf.Tensor(b'0.512179', shape=(), dtype=string)
# tf.Tensor(b'0.511512', shape=(), dtype=string)
# tf.Tensor(b'0.509541', shape=(), dtype=string)
# tf.Tensor(b'0.512621', shape=(), dtype=string)
# tf.Tensor(b'0.510954', shape=(), dtype=string)
# tf.Tensor(b'0.513594', shape=(), dtype=string)
# tf.Tensor(b'0.524745', shape=(), dtype=string)
# tf.Tensor(b'0.525526', shape=(), dtype=string)
# tf.Tensor(b'0.509510', shape=(), dtype=string)
# tf.Tensor(b'0.503362', shape=(), dtype=string)
# tf.Tensor(b'0.508203', shape=(), dtype=string)
# tf.Tensor(b'0.508229', shape=(), dtype=string)
# tf.Tensor(b'0.510422', shape=(), dtype=string)
# tf.Tensor(b'0.520339', shape=(), dtype=string)
# tf.Tensor(b'0.523731', shape=(), dtype=string)
# tf.Tensor(b'0.537153', shape=(), dtype=string)
# tf.Tensor(b'0.552788', shape=(), dtype=string)
# tf.Tensor(b'0.552405', shape=(), dtype=string)
# tf.Tensor(b'0.553288', shape=(), dtype=string)
# tf.Tensor(b'0.544975', shape=(), dtype=string)
# tf.Tensor(b'0.536631', shape=(), dtype=string)
# tf.Tensor(b'0.542680', shape=(), dtype=string)
# tf.Tensor(b'0.543621', shape=(), dtype=string)
# tf.Tensor(b'0.547592', shape=(), dtype=string)
# tf.Tensor(b'0.549628', shape=(), dtype=string)
# tf.Tensor(b'0.550930', shape=(), dtype=string)
# tf.Tensor(b'0.546694', shape=(), dtype=string)
# tf.Tensor(b'0.552067', shape=(), dtype=string)
# tf.Tensor(b'0.548669', shape=(), dtype=string)
# tf.Tensor(b'0.548536', shape=(), dtype=string)
# tf.Tensor(b'0.550498', shape=(), dtype=string)
# tf.Tensor(b'0.548355', shape=(), dtype=string)
# tf.Tensor(b'0.549018', shape=(), dtype=string)
# tf.Tensor(b'0.546510', shape=(), dtype=string)
# tf.Tensor(b'0.550160', shape=(), dtype=string)
# tf.Tensor(b'0.548083', shape=(), dtype=string)
# tf.Tensor(b'0.547457', shape=(), dtype=string)
# tf.Tensor(b'0.546592', shape=(), dtype=string)
# tf.Tensor(b'0.545089', shape=(), dtype=string)
# tf.Tensor(b'0.548257', shape=(), dtype=string)
# tf.Tensor(b'0.549963', shape=(), dtype=string)
# tf.Tensor(b'0.546701', shape=(), dtype=string)
# tf.Tensor(b'0.546700', shape=(), dtype=string)
# tf.Tensor(b'0.547213', shape=(), dtype=string)
# tf.Tensor(b'0.545136', shape=(), dtype=string)
# tf.Tensor(b'0.546656', shape=(), dtype=string)
# tf.Tensor(b'0.546309', shape=(), dtype=string)
# tf.Tensor(b'0.544793', shape=(), dtype=string)
# tf.Tensor(b'0.546843', shape=(), dtype=string)
# tf.Tensor(b'0.548776', shape=(), dtype=string)
# tf.Tensor(b'0.544988', shape=(), dtype=string)
# tf.Tensor(b'0.547993', shape=(), dtype=string)
# tf.Tensor(b'0.544707', shape=(), dtype=string)
# tf.Tensor(b'0.546064', shape=(), dtype=string)
# tf.Tensor(b'0.544826', shape=(), dtype=string)
# tf.Tensor(b'0.542315', shape=(), dtype=string)
# tf.Tensor(b'0.541063', shape=(), dtype=string)
# tf.Tensor(b'0.545535', shape=(), dtype=string)
# tf.Tensor(b'0.545325', shape=(), dtype=string)
# tf.Tensor(b'0.542182', shape=(), dtype=string)
# tf.Tensor(b'0.538492', shape=(), dtype=string)
# tf.Tensor(b'0.539324', shape=(), dtype=string)
# tf.Tensor(b'0.539022', shape=(), dtype=string)
# tf.Tensor(b'0.538993', shape=(), dtype=string)
# tf.Tensor(b'0.539382', shape=(), dtype=string)
# tf.Tensor(b'0.538175', shape=(), dtype=string)
# tf.Tensor(b'0.539430', shape=(), dtype=string)
# tf.Tensor(b'0.538493', shape=(), dtype=string)
# tf.Tensor(b'0.533465', shape=(), dtype=string)
# tf.Tensor(b'0.538453', shape=(), dtype=string)
# tf.Tensor(b'0.528253', shape=(), dtype=string)
# tf.Tensor(b'0.528901', shape=(), dtype=string)
# tf.Tensor(b'0.521164', shape=(), dtype=string)
# tf.Tensor(b'0.518779', shape=(), dtype=string)
# tf.Tensor(b'0.523135', shape=(), dtype=string)
# tf.Tensor(b'0.521510', shape=(), dtype=string)
# tf.Tensor(b'0.525629', shape=(), dtype=string)
# tf.Tensor(b'0.524403', shape=(), dtype=string)
# tf.Tensor(b'0.526366', shape=(), dtype=string)
# tf.Tensor(b'0.531331', shape=(), dtype=string)
# tf.Tensor(b'0.527631', shape=(), dtype=string)
# tf.Tensor(b'0.529181', shape=(), dtype=string)
# tf.Tensor(b'0.525390', shape=(), dtype=string)
# tf.Tensor(b'0.526484', shape=(), dtype=string)
# tf.Tensor(b'0.524160', shape=(), dtype=string)
# tf.Tensor(b'0.530213', shape=(), dtype=string)
# tf.Tensor(b'0.529694', shape=(), dtype=string)
# tf.Tensor(b'0.527046', shape=(), dtype=string)
# tf.Tensor(b'0.529736', shape=(), dtype=string)
# tf.Tensor(b'0.530091', shape=(), dtype=string)
# tf.Tensor(b'0.528071', shape=(), dtype=string)
# tf.Tensor(b'0.532072', shape=(), dtype=string)
# tf.Tensor(b'0.525932', shape=(), dtype=string)
# tf.Tensor(b'0.529950', shape=(), dtype=string)
# tf.Tensor(b'0.527138', shape=(), dtype=string)
# tf.Tensor(b'0.529934', shape=(), dtype=string)
# tf.Tensor(b'0.529531', shape=(), dtype=string)
# tf.Tensor(b'0.530273', shape=(), dtype=string)
# tf.Tensor(b'0.525754', shape=(), dtype=string)
# tf.Tensor(b'0.524828', shape=(), dtype=string)
# tf.Tensor(b'0.527118', shape=(), dtype=string)
# tf.Tensor(b'0.532177', shape=(), dtype=string)
# tf.Tensor(b'0.530073', shape=(), dtype=string)
# tf.Tensor(b'0.527827', shape=(), dtype=string)
# tf.Tensor(b'0.523805', shape=(), dtype=string)
# tf.Tensor(b'0.526303', shape=(), dtype=string)
# tf.Tensor(b'0.531637', shape=(), dtype=string)
# tf.Tensor(b'0.528327', shape=(), dtype=string)
# tf.Tensor(b'0.529666', shape=(), dtype=string)
# tf.Tensor(b'0.527172', shape=(), dtype=string)
# tf.Tensor(b'0.528214', shape=(), dtype=string)
# tf.Tensor(b'0.530183', shape=(), dtype=string)
# tf.Tensor(b'0.532660', shape=(), dtype=string)
# tf.Tensor(b'0.528338', shape=(), dtype=string)
# tf.Tensor(b'0.525973', shape=(), dtype=string)
# tf.Tensor(b'0.529731', shape=(), dtype=string)
# tf.Tensor(b'0.529324', shape=(), dtype=string)
# tf.Tensor(b'0.527956', shape=(), dtype=string)
# tf.Tensor(b'0.527006', shape=(), dtype=string)
# tf.Tensor(b'0.525525', shape=(), dtype=string)
# tf.Tensor(b'0.530005', shape=(), dtype=string)
# tf.Tensor(b'0.530386', shape=(), dtype=string)
# tf.Tensor(b'0.528547', shape=(), dtype=string)
# tf.Tensor(b'0.523903', shape=(), dtype=string)
# tf.Tensor(b'0.523010', shape=(), dtype=string)
# tf.Tensor(b'0.523267', shape=(), dtype=string)
# tf.Tensor(b'0.520223', shape=(), dtype=string)
# tf.Tensor(b'0.521884', shape=(), dtype=string)
# tf.Tensor(b'0.517187', shape=(), dtype=string)
# tf.Tensor(b'0.518424', shape=(), dtype=string)
# tf.Tensor(b'0.518896', shape=(), dtype=string)
# tf.Tensor(b'0.518232', shape=(), dtype=string)
# tf.Tensor(b'0.518348', shape=(), dtype=string)
# tf.Tensor(b'0.516939', shape=(), dtype=string)
# tf.Tensor(b'0.515397', shape=(), dtype=string)
# tf.Tensor(b'0.519577', shape=(), dtype=string)
# tf.Tensor(b'0.518088', shape=(), dtype=string)
# tf.Tensor(b'0.520026', shape=(), dtype=string)
# tf.Tensor(b'0.518893', shape=(), dtype=string)
# tf.Tensor(b'0.516977', shape=(), dtype=string)
# tf.Tensor(b'0.517042', shape=(), dtype=string)
# tf.Tensor(b'0.516977', shape=(), dtype=string)
# tf.Tensor(b'0.517588', shape=(), dtype=string)
# tf.Tensor(b'0.516083', shape=(), dtype=string)
# tf.Tensor(b'0.517146', shape=(), dtype=string)
# tf.Tensor(b'0.519447', shape=(), dtype=string)
# tf.Tensor(b'0.516751', shape=(), dtype=string)
# tf.Tensor(b'0.517448', shape=(), dtype=string)
# tf.Tensor(b'0.520582', shape=(), dtype=string)
# tf.Tensor(b'0.520838', shape=(), dtype=string)
# tf.Tensor(b'0.519132', shape=(), dtype=string)
# tf.Tensor(b'0.535190', shape=(), dtype=string)
# tf.Tensor(b'0.538532', shape=(), dtype=string)
# tf.Tensor(b'0.538300', shape=(), dtype=string)
# tf.Tensor(b'0.538926', shape=(), dtype=string)
# tf.Tensor(b'0.537807', shape=(), dtype=string)
# tf.Tensor(b'0.540347', shape=(), dtype=string)
# tf.Tensor(b'0.538543', shape=(), dtype=string)
# tf.Tensor(b'0.541091', shape=(), dtype=string)
# tf.Tensor(b'0.539871', shape=(), dtype=string)
# tf.Tensor(b'0.538395', shape=(), dtype=string)
# tf.Tensor(b'0.538046', shape=(), dtype=string)
# tf.Tensor(b'0.537386', shape=(), dtype=string)
# tf.Tensor(b'0.537576', shape=(), dtype=string)
# tf.Tensor(b'0.537240', shape=(), dtype=string)
# tf.Tensor(b'0.537459', shape=(), dtype=string)
# tf.Tensor(b'0.534896', shape=(), dtype=string)
# tf.Tensor(b'0.531620', shape=(), dtype=string)
# tf.Tensor(b'0.535555', shape=(), dtype=string)
# tf.Tensor(b'0.539852', shape=(), dtype=string)
# tf.Tensor(b'0.539936', shape=(), dtype=string)
# tf.Tensor(b'0.539059', shape=(), dtype=string)
# tf.Tensor(b'0.539466', shape=(), dtype=string)
# tf.Tensor(b'0.538071', shape=(), dtype=string)
# tf.Tensor(b'0.540720', shape=(), dtype=string)
# tf.Tensor(b'0.541293', shape=(), dtype=string)
# tf.Tensor(b'0.538464', shape=(), dtype=string)
# tf.Tensor(b'0.538712', shape=(), dtype=string)
# tf.Tensor(b'0.533816', shape=(), dtype=string)
# tf.Tensor(b'0.536098', shape=(), dtype=string)
# tf.Tensor(b'0.543089', shape=(), dtype=string)
# tf.Tensor(b'0.538585', shape=(), dtype=string)
# tf.Tensor(b'0.539505', shape=(), dtype=string)
# tf.Tensor(b'0.529060', shape=(), dtype=string)
# tf.Tensor(b'0.530897', shape=(), dtype=string)
# tf.Tensor(b'0.527259', shape=(), dtype=string)
# tf.Tensor(b'0.532229', shape=(), dtype=string)
# tf.Tensor(b'0.529319', shape=(), dtype=string)
# tf.Tensor(b'0.524042', shape=(), dtype=string)
# tf.Tensor(b'0.535094', shape=(), dtype=string)
# tf.Tensor(b'0.535014', shape=(), dtype=string)
# tf.Tensor(b'0.542593', shape=(), dtype=string)
# tf.Tensor(b'0.538567', shape=(), dtype=string)
# tf.Tensor(b'0.539098', shape=(), dtype=string)
# tf.Tensor(b'0.534736', shape=(), dtype=string)
# tf.Tensor(b'0.533538', shape=(), dtype=string)
# tf.Tensor(b'0.529392', shape=(), dtype=string)
# tf.Tensor(b'0.535398', shape=(), dtype=string)
# tf.Tensor(b'0.539677', shape=(), dtype=string)
# tf.Tensor(b'0.537365', shape=(), dtype=string)
# tf.Tensor(b'0.528544', shape=(), dtype=string)
# tf.Tensor(b'0.530636', shape=(), dtype=string)
# tf.Tensor(b'0.530056', shape=(), dtype=string)
# tf.Tensor(b'0.537547', shape=(), dtype=string)
# tf.Tensor(b'0.535073', shape=(), dtype=string)
# tf.Tensor(b'0.530788', shape=(), dtype=string)
# tf.Tensor(b'0.533810', shape=(), dtype=string)
# tf.Tensor(b'0.543207', shape=(), dtype=string)
# tf.Tensor(b'0.542268', shape=(), dtype=string)
# tf.Tensor(b'0.533835', shape=(), dtype=string)
# tf.Tensor(b'0.535540', shape=(), dtype=string)
# tf.Tensor(b'0.532036', shape=(), dtype=string)
# tf.Tensor(b'0.532107', shape=(), dtype=string)
# tf.Tensor(b'0.533555', shape=(), dtype=string)
# tf.Tensor(b'0.534023', shape=(), dtype=string)
# tf.Tensor(b'0.535581', shape=(), dtype=string)
# tf.Tensor(b'0.537212', shape=(), dtype=string)
# tf.Tensor(b'0.535435', shape=(), dtype=string)
# tf.Tensor(b'0.540245', shape=(), dtype=string)
# tf.Tensor(b'0.533850', shape=(), dtype=string)
# tf.Tensor(b'0.531570', shape=(), dtype=string)
# tf.Tensor(b'0.535367', shape=(), dtype=string)
# tf.Tensor(b'0.535540', shape=(), dtype=string)
# tf.Tensor(b'0.539292', shape=(), dtype=string)
# tf.Tensor(b'0.534878', shape=(), dtype=string)
# tf.Tensor(b'0.540535', shape=(), dtype=string)
# tf.Tensor(b'0.533852', shape=(), dtype=string)
# tf.Tensor(b'0.530206', shape=(), dtype=string)
# tf.Tensor(b'0.534077', shape=(), dtype=string)
# tf.Tensor(b'0.539710', shape=(), dtype=string)
# tf.Tensor(b'0.538544', shape=(), dtype=string)
# tf.Tensor(b'0.540294', shape=(), dtype=string)
# tf.Tensor(b'0.535973', shape=(), dtype=string)
# tf.Tensor(b'0.534534', shape=(), dtype=string)
# tf.Tensor(b'0.539905', shape=(), dtype=string)
# tf.Tensor(b'0.533673', shape=(), dtype=string)
# tf.Tensor(b'0.532360', shape=(), dtype=string)
# tf.Tensor(b'0.530315', shape=(), dtype=string)
# tf.Tensor(b'0.537313', shape=(), dtype=string)
# tf.Tensor(b'0.536854', shape=(), dtype=string)
# tf.Tensor(b'0.534363', shape=(), dtype=string)
# tf.Tensor(b'0.536617', shape=(), dtype=string)
# tf.Tensor(b'0.535264', shape=(), dtype=string)
# tf.Tensor(b'0.532528', shape=(), dtype=string)
# tf.Tensor(b'0.534755', shape=(), dtype=string)
# tf.Tensor(b'0.535534', shape=(), dtype=string)
# tf.Tensor(b'0.535787', shape=(), dtype=string)
# tf.Tensor(b'0.539553', shape=(), dtype=string)
# tf.Tensor(b'0.533273', shape=(), dtype=string)
# tf.Tensor(b'0.537988', shape=(), dtype=string)
# tf.Tensor(b'0.538638', shape=(), dtype=string)
# tf.Tensor(b'0.537137', shape=(), dtype=string)
# tf.Tensor(b'0.582456', shape=(), dtype=string)
# tf.Tensor(b'0.562559', shape=(), dtype=string)
# tf.Tensor(b'0.548703', shape=(), dtype=string)
# tf.Tensor(b'0.553920', shape=(), dtype=string)
# tf.Tensor(b'0.563572', shape=(), dtype=string)
# tf.Tensor(b'0.549595', shape=(), dtype=string)
# tf.Tensor(b'0.531302', shape=(), dtype=string)
# tf.Tensor(b'0.539555', shape=(), dtype=string)
# tf.Tensor(b'0.549878', shape=(), dtype=string)
# tf.Tensor(b'0.537453', shape=(), dtype=string)
# tf.Tensor(b'0.546188', shape=(), dtype=string)
# tf.Tensor(b'0.536950', shape=(), dtype=string)
# tf.Tensor(b'0.544950', shape=(), dtype=string)
# tf.Tensor(b'0.542451', shape=(), dtype=string)
# tf.Tensor(b'0.516699', shape=(), dtype=string)
# tf.Tensor(b'0.545332', shape=(), dtype=string)
# tf.Tensor(b'0.528444', shape=(), dtype=string)
# tf.Tensor(b'0.550572', shape=(), dtype=string)
# tf.Tensor(b'0.536555', shape=(), dtype=string)
# tf.Tensor(b'0.559065', shape=(), dtype=string)
# tf.Tensor(b'0.528740', shape=(), dtype=string)
# tf.Tensor(b'0.540913', shape=(), dtype=string)
# tf.Tensor(b'0.540821', shape=(), dtype=string)
# tf.Tensor(b'0.537901', shape=(), dtype=string)
# tf.Tensor(b'0.536971', shape=(), dtype=string)
# tf.Tensor(b'0.533794', shape=(), dtype=string)
# tf.Tensor(b'0.522734', shape=(), dtype=string)
# tf.Tensor(b'0.539551', shape=(), dtype=string)
# tf.Tensor(b'0.528158', shape=(), dtype=string)
# tf.Tensor(b'0.529226', shape=(), dtype=string)
# tf.Tensor(b'0.540096', shape=(), dtype=string)
# tf.Tensor(b'0.535807', shape=(), dtype=string)
# tf.Tensor(b'0.530628', shape=(), dtype=string)
# tf.Tensor(b'0.534492', shape=(), dtype=string)
# tf.Tensor(b'0.533085', shape=(), dtype=string)
# tf.Tensor(b'0.488561', shape=(), dtype=string)
# tf.Tensor(b'0.540790', shape=(), dtype=string)
# tf.Tensor(b'0.535849', shape=(), dtype=string)
# tf.Tensor(b'0.537611', shape=(), dtype=string)
# tf.Tensor(b'0.498120', shape=(), dtype=string)
# tf.Tensor(b'0.548877', shape=(), dtype=string)
# tf.Tensor(b'0.532117', shape=(), dtype=string)
# tf.Tensor(b'0.522935', shape=(), dtype=string)
# tf.Tensor(b'0.533551', shape=(), dtype=string)
# tf.Tensor(b'0.522803', shape=(), dtype=string)
# tf.Tensor(b'0.517936', shape=(), dtype=string)
# tf.Tensor(b'0.521826', shape=(), dtype=string)
# tf.Tensor(b'0.534447', shape=(), dtype=string)
# tf.Tensor(b'0.498306', shape=(), dtype=string)
# tf.Tensor(b'0.533532', shape=(), dtype=string)
# tf.Tensor(b'0.527375', shape=(), dtype=string)
# tf.Tensor(b'0.501472', shape=(), dtype=string)
# tf.Tensor(b'0.527228', shape=(), dtype=string)
# tf.Tensor(b'0.510502', shape=(), dtype=string)
# tf.Tensor(b'0.519626', shape=(), dtype=string)
# tf.Tensor(b'0.522766', shape=(), dtype=string)
# tf.Tensor(b'0.511536', shape=(), dtype=string)
# tf.Tensor(b'0.502639', shape=(), dtype=string)
# tf.Tensor(b'0.509346', shape=(), dtype=string)
# tf.Tensor(b'0.514000', shape=(), dtype=string)
# tf.Tensor(b'0.519432', shape=(), dtype=string)
# tf.Tensor(b'0.516722', shape=(), dtype=string)
# tf.Tensor(b'0.515750', shape=(), dtype=string)
# tf.Tensor(b'0.529775', shape=(), dtype=string)
# tf.Tensor(b'0.502261', shape=(), dtype=string)
# tf.Tensor(b'0.506172', shape=(), dtype=string)
# tf.Tensor(b'0.506604', shape=(), dtype=string)
# tf.Tensor(b'0.527414', shape=(), dtype=string)
# tf.Tensor(b'0.525476', shape=(), dtype=string)
# tf.Tensor(b'0.515670', shape=(), dtype=string)
# tf.Tensor(b'0.520039', shape=(), dtype=string)
# tf.Tensor(b'0.520966', shape=(), dtype=string)
# tf.Tensor(b'0.521965', shape=(), dtype=string)
# tf.Tensor(b'0.521946', shape=(), dtype=string)
# tf.Tensor(b'0.520383', shape=(), dtype=string)
# tf.Tensor(b'0.516190', shape=(), dtype=string)
# tf.Tensor(b'0.518897', shape=(), dtype=string)
# tf.Tensor(b'0.521076', shape=(), dtype=string)
# tf.Tensor(b'0.522310', shape=(), dtype=string)
# tf.Tensor(b'0.523699', shape=(), dtype=string)
# tf.Tensor(b'0.521099', shape=(), dtype=string)
# tf.Tensor(b'0.512284', shape=(), dtype=string)
# tf.Tensor(b'0.510188', shape=(), dtype=string)
# tf.Tensor(b'0.513161', shape=(), dtype=string)
# tf.Tensor(b'0.507269', shape=(), dtype=string)
# tf.Tensor(b'0.510822', shape=(), dtype=string)
# tf.Tensor(b'0.511760', shape=(), dtype=string)
# tf.Tensor(b'0.513385', shape=(), dtype=string)
# tf.Tensor(b'0.511127', shape=(), dtype=string)
# tf.Tensor(b'0.519588', shape=(), dtype=string)
# tf.Tensor(b'0.515945', shape=(), dtype=string)
# tf.Tensor(b'0.520059', shape=(), dtype=string)
# tf.Tensor(b'0.520092', shape=(), dtype=string)
# tf.Tensor(b'0.520268', shape=(), dtype=string)
# tf.Tensor(b'0.518651', shape=(), dtype=string)
# tf.Tensor(b'0.511431', shape=(), dtype=string)
# tf.Tensor(b'0.514763', shape=(), dtype=string)
# tf.Tensor(b'0.519017', shape=(), dtype=string)
# tf.Tensor(b'0.520689', shape=(), dtype=string)
# tf.Tensor(b'0.511485', shape=(), dtype=string)
# tf.Tensor(b'0.520636', shape=(), dtype=string)
# tf.Tensor(b'0.519229', shape=(), dtype=string)
# tf.Tensor(b'0.519793', shape=(), dtype=string)
# tf.Tensor(b'0.521124', shape=(), dtype=string)
# tf.Tensor(b'0.516009', shape=(), dtype=string)
# tf.Tensor(b'0.513543', shape=(), dtype=string)
# tf.Tensor(b'0.518447', shape=(), dtype=string)
# tf.Tensor(b'0.518837', shape=(), dtype=string)
# tf.Tensor(b'0.521155', shape=(), dtype=string)
# tf.Tensor(b'0.521393', shape=(), dtype=string)
# tf.Tensor(b'0.516118', shape=(), dtype=string)
# tf.Tensor(b'0.521288', shape=(), dtype=string)
# tf.Tensor(b'0.520722', shape=(), dtype=string)
# tf.Tensor(b'0.521457', shape=(), dtype=string)
# tf.Tensor(b'0.521844', shape=(), dtype=string)
# tf.Tensor(b'0.515736', shape=(), dtype=string)
# tf.Tensor(b'0.527378', shape=(), dtype=string)
# tf.Tensor(b'0.535609', shape=(), dtype=string)
# tf.Tensor(b'0.539343', shape=(), dtype=string)
# tf.Tensor(b'0.530825', shape=(), dtype=string)
# tf.Tensor(b'0.524130', shape=(), dtype=string)
# tf.Tensor(b'0.524032', shape=(), dtype=string)
# tf.Tensor(b'0.526714', shape=(), dtype=string)
# tf.Tensor(b'0.526102', shape=(), dtype=string)
# tf.Tensor(b'0.527175', shape=(), dtype=string)
# tf.Tensor(b'0.532509', shape=(), dtype=string)
# tf.Tensor(b'0.530660', shape=(), dtype=string)
# tf.Tensor(b'0.526724', shape=(), dtype=string)
# tf.Tensor(b'0.528347', shape=(), dtype=string)
# tf.Tensor(b'0.527654', shape=(), dtype=string)
# tf.Tensor(b'0.525994', shape=(), dtype=string)
# tf.Tensor(b'0.525576', shape=(), dtype=string)
# tf.Tensor(b'0.526775', shape=(), dtype=string)
# tf.Tensor(b'0.524427', shape=(), dtype=string)
# tf.Tensor(b'0.532406', shape=(), dtype=string)
# tf.Tensor(b'0.522538', shape=(), dtype=string)
# tf.Tensor(b'0.528812', shape=(), dtype=string)
# tf.Tensor(b'0.525877', shape=(), dtype=string)
# tf.Tensor(b'0.529842', shape=(), dtype=string)
# tf.Tensor(b'0.531921', shape=(), dtype=string)
# tf.Tensor(b'0.523582', shape=(), dtype=string)
# tf.Tensor(b'0.529168', shape=(), dtype=string)
# tf.Tensor(b'0.528694', shape=(), dtype=string)
# tf.Tensor(b'0.537745', shape=(), dtype=string)
# tf.Tensor(b'0.536266', shape=(), dtype=string)
# tf.Tensor(b'0.536656', shape=(), dtype=string)
# tf.Tensor(b'0.530111', shape=(), dtype=string)
# tf.Tensor(b'0.530169', shape=(), dtype=string)
# tf.Tensor(b'0.531166', shape=(), dtype=string)
